# %% [markdown]
# Create a Python Class for managing student details and marks.
# Define the class and implement the methods of the student class in a menu-driven program for different types of users

# %%
class Student():#creating a class
    def init(self):
        self.file = ""
        
    def details(self):#defining a function which will show student details
        x= file.readlines()
        for i in x:
          print(i)

    def search(self,name):#function to search student detials
        x= file.readlines()
        for i in x:
            k = i.strip().split(",")            
            if name in k:
               print("exist")
               print(k)
    def update(self,StudentID,Name,Math,Science,History):#function to update student details
        file.write(StudentID+",")
        file.write(Name+",")
        file.write(Math+",")
        file.write(Science+",")
        file.write(History+"\n")

    
SM =Student()
while True:
    print("="*30,"STUDENT MANAGEMENT","="*30)
    print("1.SEARCH A STUDENT \t\t\t 2.UPDATE THE STUDENT DATA")
    print("3.STUDENT DETAILS \t\t\t 4.EXIT...!")
    print("="*80)
   
    choice = int(input("enter choice:"))

    if choice == 1:
        name=input("id")
        file=open("STUDENT DETAILS.csv","r")
        SM.search(name)
    if choice == 2:
        file=open("STUDENT DETAILS.csv","a")
        id=input("id")
        Name=input("name")
       
        Math=input("maths")
        Science=input("science")
        History=input("history")
        SM.update(id,Name,Math,Science,History,)
    
    if choice == 3:
        file=open("STUDENT DETAILS.csv","r")
        SM.details()
    if choice == 4:
        break
# Out:
# ============================== STUDENT MANAGEMENT ==============================
# 1.SEARCH A STUDENT 			 2.UPDATE THE STUDENT DATA
# 3.STUDENT DETAILS 			 4.EXIT...!
# ...
# StudentID,Name,Math,Science,History
#
# 1,nikhil,90,88,78
#
# 2,Baby,85,91,80
#
# 3,Charlie,92,89,85
#
# 4,David,95,87,91
#
# 5,Emily,88,90,87
#
# 6,Franky,89,86,82
#
# 7,biju,91,94,89
#
# 8,benny,87,92,86
#
# 9,luffy,94,88,90
#
# 10,Jack,88,85,89
#
#
#
# ============================== STUDENT MANAGEMENT ==============================
# 1.SEARCH A STUDENT 			 2.UPDATE THE STUDENT DATA
# 3.STUDENT DETAILS 			 4.EXIT...!
# ...
# ============================== STUDENT MANAGEMENT ==============================
# 1.SEARCH A STUDENT 			 2.UPDATE THE STUDENT DATA
# 3.STUDENT DETAILS 			 4.EXIT...!
# ...
# exist
# ['12', 'jaise', '45', '78', '96']
# ============================== STUDENT MANAGEMENT ==============================
# 1.SEARCH A STUDENT 			 2.UPDATE THE STUDENT DATA
# 3.STUDENT DETAILS 			 4.EXIT...!
# ...
